# %%
from utils_processing.utils import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(2000, 4000)
print_characteristics(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)
# Walking Frame
#        skew  percentile       iqr  kurtosis  std_deviation  derivative  \
# 0 -0.036556    0.208514  0.013916 -0.313109       0.011038    0.000231
# 1 -0.520783    0.213194  0.013000  0.055925       0.013849   -0.000087
# 2  0.995854    0.213196  0.024170 -0.020581       0.015962   -0.000256
# 3 -0.585793    0.213197  0.008545  0.170060       0.007535   -0.000193
# 4 -0.190467    0.213194  0.019653 -0.677261       0.014081   -0.000197
#
#        norm  label
# 0  0.048828      0
# 1 -0.044678      0
# 2  0.129395      0
# ...

# %%
def create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame):
    u_frame = pd.concat([su_frame, eu_frame, lu_frame])
    u_frame['label_direction'] = 0
    d_frame = pd.concat([sd_frame, ed_frame, ld_frame])
    d_frame['label_direction'] = 1
    return u_frame, d_frame

# %%
def create_direction_dataset(up_frame, down_frame):
    u_features_array = up_frame.as_matrix(columns=up_frame.columns)
    d_features_array = down_frame.as_matrix(columns=down_frame.columns)
    X = np.concatenate([u_features_array, d_features_array])
    Y = X[:,8]
    X = X[:,:7]
    return X, Y

# %%
up_frame, down_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)

# %%
display(up_frame, down_frame)
# Out:
#          skew  percentile       iqr  kurtosis  std_deviation  derivative  \
# 0   -0.058054    0.277353  0.249268 -1.535585       0.125822   -0.002033
# 1   -0.151656    0.208513  0.105469 -1.211670       0.058574   -0.000976
# 2    0.534511    0.213185  0.064880 -0.810616       0.045345   -0.000892
# 3   -0.196613    0.267249  0.040527 -1.106622       0.024263   -0.000451
# 4   -0.628156    0.577345  0.007202 -1.500000       0.006294   -0.000122
# 5    1.042597    0.208505  0.133057 -0.047701       0.119294   -0.002537
# 6   -0.081621    0.223588  0.109009 -1.441910       0.058519   -0.000995
# 7    0.618543    0.333325  0.043457 -1.252627       0.025957   -0.000378
# 8    0.812884    0.249984  0.185303 -0.754879       0.124688   -0.002281
# 9    0.661421    0.258188  0.054810 -0.915885       0.036313   -0.000546
# 10   0.679792    0.258190  0.025757 -0.304208       0.022940   -0.000376
# 11  -0.743067    0.499996  0.006836 -1.076540       0.005389   -0.000003
# ...

# %%
def visualize_direction_features(up_frame, down_frame):
    u_features_array = up_frame.as_matrix(columns=up_frame.columns)
    d_features_array = down_frame.as_matrix(columns=down_frame.columns)
    X = np.concatenate([u_features_array, d_features_array])
    print(X.shape)
    
    windows_map = { 0:{'values':X[:,0], 'legend': 'skewness'}, 1:{'values':X[:,5], 'legend': 'gradient'},
               2:{'values':X[:,3], 'legend':'kurtosis'}, 3:{'values':X[:,4], 'legend':'std deviation'},
               4:{'values':X[:,1], 'legend':'percentile_windows'}, 5:{'values':X[:,2], 'legend': 'iqr'},
               6:{'values':X[:,6], 'legend':'norm'}, 7:{'values':X[:,8], 'legend':'labels'}}

    combos = list(combinations(list(range(len(windows_map.keys())-1)), 2))
#     print(len(combos))

    for combo in combos:
        fig = plt.figure()
        ax1 = fig.add_subplot(111)
        ax1.scatter(windows_map[combo[0]]['values'][:len(up_frame)], windows_map[combo[1]]['values'][:len(up_frame)], c='r', alpha=0.5, label='up')
        ax1.scatter(windows_map[combo[0]]['values'][len(up_frame):], windows_map[combo[1]]['values'][len(up_frame):], c='b', alpha=0.5, label='down')
        ax = plt.subplot()
        ax.set_xlabel(windows_map[combo[0]]['legend'])
        ax.set_ylabel(windows_map[combo[1]]['legend'])
        ax.legend()
        ax.grid(True)
        plt.show()

# %% [markdown]
# ## Window 4 & 8s

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(4000, 8000)
print_characteristics(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
walking_frame, vertical_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
display(walking_frame.head(), walking_frame.tail())
display(vertical_frame.head(), vertical_frame.tail())
visualize_direction_features(walking_frame, vertical_frame)
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)
# Walking Frame
#        skew  percentile       iqr  kurtosis  std_deviation  derivative  \
# 0  0.390242    0.149071  0.022705 -0.570442       0.014271   -0.000035
# 1  0.432045    0.150749  0.016479  0.540399       0.018278   -0.000322
# 2  0.036924    0.150750  0.021545 -0.707460       0.015993    0.000060
# 3 -0.351840    0.149066  0.021973 -0.596747       0.016385    0.000205
# 4 -0.038243    0.149067  0.027832 -1.106959       0.016911   -0.000004
#
#        norm  label
# 0  0.002930      0
# 1  0.006592      0
# 2  0.048828      0
# ...

# %% [markdown]
# ## Window 2 & 4s

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(2000, 4000)
print_characteristics(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
walking_frame, vertical_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
display(walking_frame.head(), walking_frame.tail())
display(vertical_frame.head(), vertical_frame.tail())
visualize_direction_features(walking_frame, vertical_frame)
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)
# Walking Frame
#        skew  percentile       iqr  kurtosis  std_deviation  derivative  \
# 0 -0.036556    0.208514  0.013916 -0.313109       0.011038    0.000231
# 1 -0.520783    0.213194  0.013000  0.055925       0.013849   -0.000087
# 2  0.995854    0.213196  0.024170 -0.020581       0.015962   -0.000256
# 3 -0.585793    0.213197  0.008545  0.170060       0.007535   -0.000193
# 4 -0.190467    0.213194  0.019653 -0.677261       0.014081   -0.000197
#
#        norm  label
# 0  0.048828      0
# 1 -0.044678      0
# 2  0.129395      0
# ...

# %% [markdown]
# ## Window 2 & 5s

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(2000, 5000)
print_characteristics(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
walking_frame, vertical_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
display(walking_frame.head(), walking_frame.tail())
display(vertical_frame.head(), vertical_frame.tail())
visualize_direction_features(walking_frame, vertical_frame)
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)
# Walking Frame
#        skew  percentile       iqr  kurtosis  std_deviation  derivative  \
# 0  0.107373    0.188982  0.015076 -0.156572       0.012485    0.000172
# 1 -0.121330    0.192445  0.022705 -0.878625       0.015277   -0.000182
# 2  1.162256    0.192446  0.014282  0.662948       0.014559   -0.000063
# 3 -0.683964    0.188977  0.013367  0.373061       0.009623   -0.000292
# 4 -0.144504    0.188976  0.019775 -0.742690       0.014611    0.000051
#
#        norm  label
# 0  0.036621      0
# 1 -0.138672      0
# 2  0.119141      0
# ...

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(2000, 4000)
print_characteristics(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
up_frame, down_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
# display(walking_frame.head(), walking_frame.tail())
# display(vertical_frame.head(), vertical_frame.tail())
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:385: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)
# Walking Frame
#        skew  percentile       iqr  kurtosis  std_deviation  derivative  \
# 0 -0.036556    0.208514  0.013916 -0.313109       0.011038    0.000231
# 1 -0.520783    0.213194  0.013000  0.055925       0.013849   -0.000087
# 2  0.995854    0.213196  0.024170 -0.020581       0.015962   -0.000256
# 3 -0.585793    0.213197  0.008545  0.170060       0.007535   -0.000193
# 4 -0.190467    0.213194  0.019653 -0.677261       0.014081   -0.000197
#
#        norm  label
# 0  0.048828      0
# 1 -0.044678      0
# 2  0.129395      0
# ...

# %%
X, Y = create_vertical_transition_dataset(up_frame, down_frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ab7d925951a3> in <module>()
# ----> 1 X, Y = create_vertical_transition_dataset(up_frame, down_frame)
#
# NameError: name 'up_frame' is not defined

# %%
print(X.shape, Y.shape)
# Out:
# (1834, 7) (1834,)

# %%
print(Y)
# Out:
# [ 0.  0.  0. ...,  1.  1.  1.]

# %%
# acc_kf_log_reg, f_kf_log_reg = KFoldVal(X, Y, classify_logistic_regression)
# acc_skf_log_reg, f_skf_log_reg = stratified_KFoldVal(X, Y, classify_logistic_regression)
# print(sum(acc_kf_log_reg)/len(acc_kf_log_reg), sum(acc_skf_log_reg)/len(acc_skf_log_reg), sum(f_kf_log_reg)/len(f_kf_log_reg), sum(f_skf_log_reg)/len(f_skf_log_reg))
# print(acc_kf_log_reg, acc_skf_log_reg, f_kf_log_reg, f_skf_log_reg)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# 0.326188550061 0.857343960636 0.876092169742 0.909054755561
# ...

# %%
def evaluate_stratified_ml_algorithms(X, Y, folds=10):
    acc_skf_lr, f_skf_lr = stratified_KFoldVal(X, Y, classify_logistic_regression, folds)
    acc_skf_sgd, f_skf_sgd = stratified_KFoldVal(X, Y, classify_sgd, folds)
    acc_skf_svm, f_skf_svm = stratified_KFoldVal(X, Y, classify_svm, folds)
    acc_skf_l_svm, f_skf_l_svm = stratified_KFoldVal(X, Y, classify_linearSVM, folds)
    acc_skf_knn, f_skf_knn = stratified_KFoldVal(X, Y, classify_knn, folds)
    acc_skf_gpc, f_skf_gpc = stratified_KFoldVal(X, Y, classify_gaussian_process_classifier, folds)
    acc_skf_nb, f_skf_nb = stratified_KFoldVal(X, Y, classify_naive_bayes, folds)
    acc_skf_dt, f_skf_dt = stratified_KFoldVal(X, Y, classify_decision_tree, folds)
    acc_skf_rf, f_skf_rf = stratified_KFoldVal(X, Y, classify_random_forest, folds)
    acc_skf_ab, f_skf_ab = stratified_KFoldVal(X, Y, classify_ada_boost, folds)
    acc_skf_gb, f_skf_gb = stratified_KFoldVal(X, Y, classify_gradient_boost, folds)
    acc_skf_nn, f_skf_nn = stratified_KFoldVal(X, Y, classify_neural_network, folds)
    
    acc_list = [acc_skf_lr, acc_skf_sgd, acc_skf_svm, acc_skf_l_svm, acc_skf_knn, acc_skf_gpc, acc_skf_nb, 
                acc_skf_dt, acc_skf_rf, acc_skf_ab, acc_skf_gb, acc_skf_nn]
    f_list = [f_skf_lr, f_skf_sgd, f_skf_svm, f_skf_l_svm, f_skf_knn, f_skf_gpc, f_skf_nb, 
                f_skf_dt, f_skf_rf, f_skf_ab, f_skf_gb, f_skf_nn]
    avg_acc_list = list(map(avg, acc_list))
    avg_f_list = list(map(avg, f_list))
    labels_list = ["LR", "SGD", "SVM", "L-SVM", "KNN", "GPC", "NB", 
                "DT", "RF", "AB", "GB", "NN"]
    return avg_acc_list, avg_f_list, labels_list

# %%
def avg(lst):
    return sum(lst)/len(lst)

# %%
avg_acc, avg_f, l_list, avg_p_list, avg_r_list = evaluate_stratified_ml_algorithms(X, Y)

print(avg_acc, avg_f, avg_p_list, avg_r_list)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
plot_performance(avg_acc, avg_f, l_list)

# %%
# l_list[0] = "LR"

# %%
N = len(avg_f)
men_means = avg_acc

ind = np.arange(N)  # the x locations for the groups
width = 0.4       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r')

women_means = avg_f
# women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, women_means, width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by algorithm')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(l_list)

ax.legend((rects1[0], rects2[0]), ('Accuracy', 'F-Score'), loc='lower right')
# ax.legend(('Accuracy', 'F-Score'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
#         ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
#                 '%d' % int(height),
#                 ha='center', va='bottom')

# autolabel(rects1)
# autolabel(rects2)

plt.show()

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(2000, 5000)
# print_characteristics(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
up_frame, down_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
# display(walking_frame.head(), walking_frame.tail())
# display(vertical_frame.head(), vertical_frame.tail())
X, Y = create_vertical_transition_dataset(up_frame, down_frame)
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:486: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)

# %%
avg_acc, avg_f, l_list = evaluate_stratified_ml_algorithms(X, Y)
print(avg_acc, avg_f)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# ...

# %%
plot_performance(avg_acc, avg_f, l_list)

# %%
visualize_direction_features(up_frame, down_frame)
# Out:
# (3483, 9)

# %%
N = len(avg_f)
men_means = avg_acc

ind = np.arange(N)  # the x locations for the groups
width = 0.4       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r')

women_means = avg_f
# women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, women_means, width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by algorithm')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(l_list)

ax.legend((rects1[0], rects2[0]), ('Accuracy', 'F-Score'), loc='lower right')
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)
# ax.legend(('Accuracy', 'F-Score'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
#         ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
#                 '%d' % int(height),
#                 ha='center', va='bottom')

# autolabel(rects1)
# autolabel(rects2)

plt.show()

# %%
X, Y = create_vertical_transition_dataset(up_frame, down_frame)

# %%
X1 = np.delete(X, np.s_[0,1,2,3,5,7], axis=1)
Y1 = Y.copy()
print(X1.shape, Y1.shape)
# Out:
# (1836, 2) (1836,)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
#   """Entry point for launching an IPython kernel.

# %%
avg_acc, avg_f, l_list = evaluate_stratified_ml_algorithms(X1, Y1)
print(avg_acc, avg_f)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [0.0, 0.21892141147010294, 0.0, 0.0, 0.37691612562611482, 0.0, 0.053456221198156684, 0.39707956174994757, 0.37449117726978309, 0.25229918583591582, 0.28638396322806059, 0.0] [0.59967688287004051, 0.52302466400827063, 0.59967688287004051, 0.59913043478260875, 0.55284539885573381, 0.59967688287004051, 0.58437633642195297, 0.52669288140599613, 0.56316270475750163, 0.57789901626501761, 0.59264704654761668, 0.59967688287004051]

# %%
plot_performance(avg_acc, avg_f, l_list)

# %%
N = len(avg_f)
men_means = avg_acc

ind = np.arange(N)  # the x locations for the groups
width = 0.4       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r')

women_means = avg_f
# women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, women_means, width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by algorithm')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(l_list)

ax.legend((rects1[0], rects2[0]), ('Accuracy', 'F-Score'), loc='lower right')
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)
# ax.legend(('Accuracy', 'F-Score'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
#         ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
#                 '%d' % int(height),
#                 ha='center', va='bottom')

# autolabel(rects1)
# autolabel(rects2)

plt.show()

# %%
def plot_performance(avg_acc, avg_f, l_list):
    N = len(avg_f)

    ind = np.arange(N)  # the x locations for the groups
    width = 0.4       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, avg_acc, width, color='r')

    rects2 = ax.bar(ind + width, avg_f, width, color='y')

    # add some text for labels, title and axes ticks
    ax.set_ylabel('Scores')
    ax.set_title('Scores by algorithm')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(l_list)

    ax.legend((rects1[0], rects2[0]), ('Accuracy', 'F-Score'), loc='lower right')

    plt.show()

# %% [markdown]
# ### 5 & 2

# %%
up_frame, down_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
X, Y = create_direction_dataset(up_frame, down_frame)
print(X.shape, Y.shape)
# Out:
# (3479, 7) (3479,)

# %%
avg_acc, avg_f, l_list, avg_p_list, avg_r_list = evaluate_stratified_ml_algorithms(X, Y)

print(avg_acc, avg_f, avg_p_list, avg_r_list)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# ...

# %%
plot_performance_all(avg_acc, avg_f, l_list, avg_p_list, avg_r_list)

# %%
plot_performance_all(avg_acc, avg_f, l_list, avg_p_list, avg_r_list)

# %% [markdown]
# ## Gradient only

# %%
X1 = np.delete(X, np.s_[0,1,2,3,4,6,7], axis=1)
Y1 = Y.copy()
print(X1.shape, Y1.shape)
# Out:
# (3479, 1) (3479,)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
#   """Entry point for launching an IPython kernel.

# %%
avg_acc, avg_f, l_list, avg_p_list, avg_r_list = evaluate_stratified_ml_algorithms(X1, Y1)

print(avg_acc, avg_f, avg_p_list, avg_r_list)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
plot_performance_all(avg_acc, avg_f, l_list, avg_p_list, avg_r_list)

# %%
fig = plt.figure()
# fig.suptitle('Classification based on pressure gradient')

ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title('Classification based on pressure gradient')

ax.set_xlabel('pressure gradient')
ax.set_ylabel('classification')
plt.plot(X1,Y1)
# plt.set_ylabel('Scores')
# plt.set_title('Scores by algorithm')

# %%
X2 = np.delete(X, np.s_[1,2,3,4,6,7], axis=1)
Y2 = Y.copy()
print(X2.shape, Y2.shape)
# Out:
# (3479, 2) (3479,)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
#   """Entry point for launching an IPython kernel.

# %%
avg_acc, avg_f, l_list, avg_p_list, avg_r_list = evaluate_stratified_ml_algorithms(X2, Y2)

print(avg_acc, avg_f, avg_p_list, avg_r_list)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# ...

# %%
plot_performance_all(avg_acc, avg_f, l_list, avg_p_list, avg_r_list)

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
Y2
# Out:
# array([ 0.,  0.,  0., ...,  1.,  1.,  1.])

# %%
hpt = LogisticRegressionCV().fit(X=X1, y=Y1)
print(hpt.score(X1,Y1))
print(hpt.f1_score(X1,Y1))
# Out:
# 0.968956596723
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-cd72e20b8d00> in <module>()
#       1 hpt = LogisticRegressionCV().fit(X=X1, y=Y1)
#       2 print(hpt.score(X1,Y1))
# ----> 3 print(hpt.f1_score(X1,Y1))
#
# AttributeError: 'LogisticRegressionCV' object has no attribute 'f1_score'

# %%
hpt.get_params()
# Out:
# {'Cs': 10,
#  'class_weight': None,
#  'cv': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1.0,
#  'max_iter': 100,
#  'multi_class': 'ovr',
#  'n_jobs': 1,
#  'penalty': 'l2',
#  'random_state': None,
#  'refit': True,
#  'scoring': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0}

# %% [markdown]
# ### 4,2

# %%
w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame = create_features_from_files(2000, 4000)
up_frame, down_frame = create_dataset_direction(w_frame, su_frame, sd_frame, eu_frame, ed_frame, lu_frame, ld_frame)
X, Y = create_direction_dataset(up_frame, down_frame)
print(X.shape, Y.shape)
# Out:
# /home/nithishr/python-projects/activity_recognition/activity_detection/utils_processing/utils.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   window['pressure_norm'] = window['pressure'].apply(lambda x: x-median)
# (3477, 7) (3477,)

# %%
avg_acc, avg_f, l_list, avg_p_list, avg_r_list = evaluate_stratified_ml_algorithms(X, Y)

print(avg_acc, avg_f, avg_p_list, avg_r_list)
# Out:
# /home/nithishr/virtual-envs/activity_recognition/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# ...

# %%
plot_performance_all(avg_acc, avg_f, l_list, avg_p_list, avg_r_list)

# %%
def plot_performance_all(avg_acc, avg_f, l_list, avg_p, avg_r):
    N = len(avg_f)

    ind = np.arange(N)  # the x locations for the groups
    width = 0.2       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, avg_acc, width, color='r')

    rects2 = ax.bar(ind + width, avg_f, width, color='g')
    rects3 = ax.bar(ind + 2*width, avg_p, width, color='b')
    rects4 = ax.bar(ind + 3*width, avg_r, width, color='y')

    # add some text for labels, title and axes ticks
#     ax.set_yticks(70,100)
    ax.set_ylabel('Scores')
    ax.set_title('Scores by algorithm')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(l_list)
    ax.set_ylim([0.7, 1.0])

    ax.legend((rects1[0], rects2[0], rects3[0], rects4[0]), ('Accuracy', 'F-Score', 'Precision', 'Recall'), loc='lower right')
    plt.grid(True)
    plt.show()

# %%
import pickle

# %%
X1.shape, Y1.shape
# Out:
# ((3479, 1), (3479,))

# %%
clf = LogisticRegressionCV(solver = 'liblinear').fit(X1, Y1)

# %%
from sklearn.externals import joblib

# %%
joblib.dump(clf, 'direction_model.pkl')
# Out:
# ['direction_model.pkl']
