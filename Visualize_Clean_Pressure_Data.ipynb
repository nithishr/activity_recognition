# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils_processing.utils import *
# %matplotlib inline

# %%
walking_files = ['Activity-Data/Samsung/Walk/Walk_N2/Walk_N2Pressure.csv', 'Activity-Data/Samsung/Walk/Walk_N_3/Walk_N_3Pressure.csv', 
                 'Activity-Data/Samsung/Walk/Walk_N/Walk_NPressure.csv', 'Activity-Data/Samsung/Walk/Walk_P1/Walk_P1Pressure.csv',
                 'Activity-Data/Samsung/Walk/Walk_P2/Walk_P2Pressure.csv', 'Activity-Data/Walking/01/Walking01Pressure.csv', 'Activity-Data/Walking/2/Walking2Pressure.csv', 
                 'Activity-Data/Walking/3/Walking3Pressure.csv', 'Activity-Data/Walking/04/Walking04Pressure.csv',
                 'Activity-Data/Walking/5/Walking5Pressure.csv']

# %%
print(len(walking_files))
# Out:
# 10

# %%
def visualize_pressure(input_file):
    df = pd.read_csv(input_file, delimiter=',', header=0)
    plt.figure()
    plt.title(input_file)
    plt.plot(df[' pressure'].values)

# %%
def remove_rows(index_list, input_file):
    df = pd.read_csv(input_file, delimiter=',', header=0)
    df1 = df.drop(index_list)
#     visualize_pressure(df1)
    output_file = input_file.split('.')[0] + '_clean.csv'
    df1.to_csv(output_file, index=False)
    return output_file

# %%
for walking_file in walking_files:
    visualize_pressure(walking_file)
#     df = pd.read_csv(walking_file, delimiter=',', header=0)
# #     print(walking_file)
#     plt.figure()
#     plt.title(walking_file)
#     plt.plot(df[' pressure'].values)
#     print(df)

# %%
visualize_pressure(walking_files[0])
indices = list(range(20)) + [178]
output_file = remove_rows(indices, walking_files[0])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[1])
indices = list(range(20))
output_file = remove_rows(indices, walking_files[1])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[2])
indices = list(range(60))
output_file = remove_rows(indices, walking_files[2])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[3])
indices = list(range(205))
output_file = remove_rows(indices, walking_files[3])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[4])
indices = list(range(20))
output_file = remove_rows(indices, walking_files[4])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[5])
indices = []
output_file = remove_rows(indices, walking_files[5])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[6])
indices = []
output_file = remove_rows(indices, walking_files[6])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[7])
indices = []
output_file = remove_rows(indices, walking_files[7])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[8])
indices = []
output_file = remove_rows(indices, walking_files[8])
visualize_pressure(output_file)

# %%
visualize_pressure(walking_files[9])
indices = []
output_file = remove_rows(indices, walking_files[9])
visualize_pressure(output_file)

# %%
climbing_files = ['Activity-Data/Samsung/Climbing_Up/Climb_Up_1/Climb_Up_1Pressure.csv', 'Activity-Data/Samsung/Climbing_Up/Climb_Up_2/Climb_Up_2Pressure.csv',    
                 'Activity-Data/Samsung/Climbing_Up/Climb_Up_3/Climb_Up_3Pressure.csv', 'Activity-Data/Samsung/Climbing_Up/Climb_Up_4/Climb_Up_4Pressure.csv',    
                 'Activity-Data/Samsung/Climbing_Up/Climb_Up_4/Climb_Up_4Pressure.csv', 'Activity-Data/Samsung/Climbing_Up/Climb_Up_6/Climb_Up_6Pressure.csv',
                 'Activity-Data/Samsung/Climbing_Up/Climb_Up_7/Climb_Up_7Pressure.csv', 'Activity-Data/Samsung/Climbing_Up/Climb_Up_8/Climb_Up_8Pressure.csv',
                 'Activity-Data/Climbing_Stairs/1/Climbing_Stairs1Pressure.csv', 'Activity-Data/Climbing_Stairs/2/Climbing_Stairs2Pressure.csv', 
                 'Activity-Data/Climbing_Stairs/3/Climbing_Stairs3Pressure.csv', 'Activity-Data/Climbing_Stairs/5/Climbing_Stairs5Pressure.csv',
                 'Activity-Data/Climbing_Stairs/6/Climbing_Stairs6Pressure.csv', 'Activity-Data/Climbing_Stairs/7/Climbing_Stairs7Pressure.csv']

# %%
print(len(climbing_files))
# Out:
# 14

# %%
for climbing_file in climbing_files:
    df = pd.read_csv(climbing_file, delimiter=',', header=0)
#     print(walking_file)
    plt.figure()
    plt.title(climbing_file)
    plt.plot(df[' pressure'].values)

# %%
visualize_pressure(climbing_files[0])
indices = list(range(5)) + list(range(18,24))
output_file = remove_rows(indices, climbing_files[0])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[1])
indices = list(range(25)) #+ list(range(18,24))
output_file = remove_rows(indices, climbing_files[1])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[2])
indices = list(range(8)) + list(range(40,42))
output_file = remove_rows(indices, climbing_files[2])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[3])
indices = list(range(8)) + list(range(20,28))
output_file = remove_rows(indices, climbing_files[3])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[4])
indices = list(range(8)) + list(range(22,29))
output_file = remove_rows(indices, climbing_files[4])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[5])
indices = list(range(8)) + list(range(42,57))
output_file = remove_rows(indices, climbing_files[5])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[6])
indices = list(range(8)) + list(range(12,32))
output_file = remove_rows(indices, climbing_files[6])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[7])
indices = list(range(8)) + list(range(38,45))
output_file = remove_rows(indices, climbing_files[7])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[8])
indices = list(range(5)) #+ list(range(40,42))
output_file = remove_rows(indices, climbing_files[8])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[9])
indices = []
output_file = remove_rows(indices, climbing_files[9])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[10])
indices = []
output_file = remove_rows(indices, climbing_files[10])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[11])
indices = list(range(5))
output_file = remove_rows(indices, climbing_files[11])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[12])
indices = list(range(5))
output_file = remove_rows(indices, climbing_files[12])
visualize_pressure(output_file)

# %%
visualize_pressure(climbing_files[13])
indices = list(range(7))
output_file = remove_rows(indices, climbing_files[13])
visualize_pressure(output_file)

# %%
downstairs_files = ['Activity-Data/Samsung/Climbing_Down/Climb_Down_1/Climb_Down_1Pressure.csv', 'Activity-Data/Samsung/Climbing_Down/Climb_Down_2/Climb_Down_2Pressure.csv',    
                    'Activity-Data/Samsung/Climbing_Down/Climb_Down_3/Climb_Down_3Pressure.csv', 'Activity-Data/Samsung/Climbing_Down/Climb_Down_6/Climb_Down_6Pressure.csv',
                    'Activity-Data/Samsung/Climbing_Down/Climb_Down_8/Climb_Down_8Pressure.csv', 'Activity-Data/Samsung/Climbing_Down/Climb_Down_9/Climb_Down_9Pressure.csv',
                    'Activity-Data/Downstairs/1/Downstairs1Pressure.csv', 'Activity-Data/Downstairs/2/Downstairs2Pressure.csv', 
                    'Activity-Data/Downstairs/3/Downstairs3Pressure.csv', 'Activity-Data/Downstairs/4/Downstairs4Pressure.csv',
                    'Activity-Data/Downstairs/5/Downstairs5Pressure.csv', 'Activity-Data/Downstairs/6/Downstairs6Pressure.csv']

# %%
print(len(downstairs_files))
# Out:
# 12

# %%
for downstairs_file in downstairs_files:
    df = pd.read_csv(downstairs_file, delimiter=',', header=0)
#     print(walking_file)
    plt.figure()
    plt.title(downstairs_file)
    plt.plot(df[' pressure'].values)

# %%
visualize_pressure(downstairs_files[0])
indices = list(range(18))
output_file = remove_rows(indices, downstairs_files[0])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[1])
indices = list(range(18)) + list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[1])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[2])
indices = list(range(12)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[2])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[3])
indices = list(range(18)) + list(range(50,53)) #+ list(range(58,63))
output_file = remove_rows(indices, downstairs_files[3])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[4])
indices = list(range(18)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[4])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[5])
indices = list(range(18)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[5])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[6])
indices = list(range(3)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[6])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[7])
indices = list(range(3)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[7])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[8])
indices = list(range(6)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[8])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[9])
indices = list(range(3)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[9])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[10])
indices = []
output_file = remove_rows(indices, downstairs_files[10])
visualize_pressure(output_file)

# %%
visualize_pressure(downstairs_files[11])
indices = list(range(3)) #+ list(range(45,53)) + list(range(58,63))
output_file = remove_rows(indices, downstairs_files[11])
visualize_pressure(output_file)

# %%
file_to_check = 'Activity-Data/1912/1/1Pressure.csv'

# %%
visualize_pressure(file_to_check)

# %%
escalator_up_files = ['Activity-Data/1912/Esc_Up/1/Esc_up_1Pressure.csv', 'Activity-Data/1912/Esc_Up/2/Esc_up_2Pressure.csv',
                     'Activity-Data/1912/Esc_Up/3/Esc_up_3Pressure.csv', 'Activity-Data/1912/Esc_Up/4/Esc_Up_4Pressure.csv']

# %%
for ef in escalator_up_files:
    visualize_pressure(ef)

# %%
lift_up_files = ['Activity-Data/1912/Lift_Up/1/Lift_up_1Pressure.csv', 'Activity-Data/1912/Lift_Up/2/Lift_up_4Pressure.csv',
                'Activity-Data/1912/Lift_Up/3/Lift_up_9Pressure.csv']

# %%
for luf in lift_up_files:
    visualize_pressure(luf)

# %%
lift_down_file = ['Activity-Data/1912/Lift_Down/1/Lift_down_9Pressure.csv']
visualize_pressure(lift_down_file[0])

# %%
stairs_down_files = ['Activity-Data/1912/Stairs_Down/1/Stairs_down_1Pressure.csv', 'Activity-Data/1912/Stairs_Down/2/Stairs_down_2Pressure.csv',
                    'Activity-Data/1912/Stairs_Down/3/Stairs_down_3Pressure.csv', 'Activity-Data/1912/Stairs_Down/4/Stairs_down_4Pressure.csv',
                    'Activity-Data/1912/Stairs_Down/5/Stairs_down_5Pressure.csv']

# %%
for sdf in stairs_down_files:
    visualize_pressure(sdf)

# %%
stairs_up_files = ['Activity-Data/1912/Stairs_Up/1/Stairs_up_1Pressure.csv', 'Activity-Data/1912/Stairs_Up/2/Stairs_up_2Pressure.csv',
                  'Activity-Data/1912/Stairs_Up/3/Stairs_up_3Pressure.csv', 'Activity-Data/1912/Stairs_Up/4/Stairs_up_4Pressure.csv',
                  'Activity-Data/1912/Stairs_Up/5/Stairs_up_5Pressure.csv']

# %%
for suf in stairs_up_files:
    visualize_pressure(suf)

# %%
walk_files = ['Activity-Data/1912/Walk/1/Walk_1Pressure.csv', 'Activity-Data/1912/Walk/2/Walk_8Pressure.csv']

# %%
for wf in walk_files:
    visualize_pressure(wf)

# %%
esc_down_files = ['Activity-Data/Samsung/061217/Esc_down/Esc_down_1/Esc_down_1Pressure.csv', 'Activity-Data/Samsung/061217/Esc_down/Esc_down_2/Esc_down_2Pressure.csv',
                 'Activity-Data/Samsung/061217/Esc_down/3/Esc_d2Pressure.csv']

# %%
for edf in esc_down_files:
    visualize_pressure(edf)

# %%
esc_up_files = ['Activity-Data/Samsung/061217/Esc_Up/Esc_Up_1/Esc_Up_1Pressure.csv', 'Activity-Data/Samsung/061217/Esc_Up/Esc_Up_2/Esc_Up_2Pressure.csv',
               'Activity-Data/Samsung/061217/Esc_Up/3/Esc_Up_3Pressure.csv', 'Activity-Data/Samsung/061217/Esc_Up/4/Esc_up_4Pressure.csv',
               'Activity-Data/Samsung/061217/Esc_Up/5/Esc_up_5Pressure.csv']

# %%
for euf in esc_up_files:
    visualize_pressure(euf)

# %%
lift_down_files = ['Activity-Data/Samsung/061217/Lift_Down/1/Lift_Down_2Pressure.csv', 'Activity-Data/Samsung/061217/Lift_Down/2/Lift_down_3Pressure.csv',
                  'Activity-Data/Samsung/061217/Lift_Down/3/Lift_down_Pressure.csv']

# %%
for ldf in lift_down_files:
    visualize_pressure(ldf)

# %%
lift_up_files = ['Activity-Data/Samsung/061217/Lift_Up/1/Lift_Up_2Pressure.csv', 'Activity-Data/Samsung/061217/Lift_Up/2/Lift_up_5Pressure.csv'
                ]

# %%
for luf in lift_up_files:
    visualize_pressure(luf)
